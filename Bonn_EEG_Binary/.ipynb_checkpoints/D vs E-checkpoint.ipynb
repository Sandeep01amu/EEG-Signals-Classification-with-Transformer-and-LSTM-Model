# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from time import sleep
import os
import pywt
import warnings
import sklearn
from tensorflow.keras import optimizers
from tensorflow.keras import layers
from keras_preprocessing.sequence import pad_sequences
import keras
import tensorflow as tf
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import optimizers
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC
# %matplotlib inline
warnings.filterwarnings("ignore",category=np.VisibleDeprecationWarning)

# %%
dirD="./Datasets/setD/"
tempD=[]
for file in os.listdir(dirD):
    fl = dirD + file
    tempD.append(fl)
tempD = sorted(tempD)

dirE="./Datasets/setE/"
tempE=[]
for file in os.listdir(dirE):
    fl = dirE + file
    tempE.append(fl)
tempE = sorted(tempE)

# %%
td=[]
st = 'A'
for i in range(len(tempD)):
    x = pd.read_table(tempD[i],header=None)
    x.columns=[st+str(i)]
    td.append(x)
    
te=[]
st = 'A'
for i in range(len(tempE)):
    x = pd.read_table(tempE[i],header=None)
    x.columns=[st+str(i)]
    te.append(x)

# %%
def table(table):
    big_table=None
    for tf in table:
        big_table=pd.concat([big_table,tf],axis=1)
    return big_table

# %%
bigD=table(td)
bigE=table(te)

head=list(bigE.columns.values)

# %%
len(bigD.columns)
# Out:
# 100

# %%
def creat_mat(mat):
    matx = np.zeros((len(mat),(len(head))))
    for i in range(len(head)):
        matx[:,i] = mat[head[i]]
        sleep(0.01)
    return matx

# %%
matD=creat_mat(bigD)
matE=creat_mat(bigE)

# %%
matD=np.nan_to_num(matD)
matE=np.nan_to_num(matE)

# %%
matD.shape,matE.shape
# Out:
# ((4097, 100), (4097, 100))

# %%
matD
# Out:
# array([[  34.,   60.,   26., ...,   67.,    5.,  -45.],
#        [  33.,   47.,   16., ...,   86.,    2.,  -53.],
#        [  28.,   38.,   13., ...,   99.,   -6.,  -51.],
#        ...,
#        [  39.,  149.,  114., ...,   17.,   36.,  -26.],
#        [  41.,  126.,   99., ...,   10.,   36.,  -14.],
#        [   7.,   42., -130., ...,   26.,   -5.,  -28.]])

# %%
matE
# Out:
# array([[ 100.,  340., -310., ..., -438., -476.,   23.],
#        [ 124.,  353.,   93., ..., -561., -518.,  144.],
#        [ 153.,  400.,  494., ..., -622., -521.,  228.],
#        ...,
#        [  57.,  512., -721., ..., -118.,  246., -155.],
#        [  95.,  130., -491., ..., -163.,  556.,    6.],
#        [ 462.,  196.,  910., ...,  -56.,  276., -221.]])

# %%
samples=np.arange(0,4097,1)
plt.figure(figsize=(16,8))
plt.subplot(2,1,1)
plt.title('Interictal')
plt.plot(samples,matD[:,0],label='Interictal')
plt.subplot(2,1,2)
plt.title('Ictal')
plt.plot(samples,matE[:,0],label='Ictal')
plt.show()

# %%
feature_size = 8
columns_name = list()
for i in range(feature_size):
    columns_name = columns_name + ['f'+str(i+1)]
columns_name = columns_name + ['class']

# %%
def features(mat):
  Fs   = 173
  fft = np.fft.fft(mat)
  mat = np.fft.ifft(fft[0:1500])
  mat = abs(np.fft.ifft(fft[0:1000]))
  lis = list()
  lis = lis + [np.max(abs(fft))]
  lis = lis + [np.min(abs(fft))]
  lis = lis + [np.mean(abs(fft))]
  lis = lis + [np.std(abs(fft))]
  lis = lis + [np.max(mat)]
  lis = lis + [np.min(mat)]
  lis = lis + [np.mean(mat)]
  lis = lis + [np.std(mat)]
  sleep(0.01)
             
  return lis

# %%
MftD = np.zeros((100,feature_size + 1))

for i in range(100):
    MftD[i,:] = features(matD[:,i]) + [0]

# %%
MftE = np.zeros((100,feature_size + 1))

for i in range(100):
    MftE[i,:] = features(matE[:,i]) + [1]

# %%
len(MftD),len(MftE)
# Out:
# (100, 100)

# %%
FCM_D = pd.DataFrame(MftD,columns=columns_name)
FCM_E = pd.DataFrame(MftE,columns=columns_name)

# %%
TotalDataset = pd.concat([FCM_D,FCM_E],ignore_index=True)

# %%
TotalDataset
# Out:
#                 f1         f2            f3            f4           f5  \
# 0    117053.000000   7.200045    761.277474   2474.221010   300.608708
# 1    130196.000000   8.000708   2762.768379   8336.409952  1973.973964
# 2    102490.000000  10.898613   1772.014880   4542.903176   555.116705
# 3    144428.000000   3.822670    962.801206   3165.257310   429.678039
# 4     63711.000000   4.639733   2397.813626   4934.202754   851.400738
# ..             ...        ...           ...           ...          ...
# 195  182731.000000   4.140197   2964.034370   6900.671072   949.526909
# 196  405933.567827  23.829796  12451.110052  33118.177387  3365.057684
# 197  206553.768555  13.807308   7000.972903  17431.403312  1554.877011
# 198  186015.216714  22.248840  12069.225734  21179.101425  3292.508700
# 199  128700.862108  12.661965   6980.974726  15056.067510  2296.802283
#
#              f6           f7          f8  class
# 0      8.923225   132.549100   54.657462    0.0
# 1      7.621243   304.299024  271.771222    0.0
# 2      7.765078   209.375622  100.340277    0.0
# 3      6.542232   166.508797   71.467323    0.0
# 4      5.001954   223.272220  117.290613    0.0
# ..          ...          ...         ...    ...
# 195    7.628541   321.787517  169.284739    1.0
# 196  584.042975  1497.708540  566.344367    1.0
# 197   70.801519   785.302431  325.527149    1.0
# 198   22.389188   897.583539  643.899324    1.0
# 199   30.885310   673.746341  331.607715    1.0
#
# [200 rows x 9 columns]

# %%
X = TotalDataset[columns_name[:-1]]
Y = TotalDataset[['class']]
X = np.asarray(X)
Y = np.asarray(Y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=0)

# %%
st_x= StandardScaler()  
X_train= st_x.fit_transform(X_train)
X_test= st_x.transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (160, 8)
# (40, 8)
# (160, 1)
# (40, 1)

# %%
x_train=X_train.reshape(X_train.shape[0],8,1)
y_train=Y_train.reshape(Y_train.shape[0],1)
x_test=X_test.reshape(X_test.shape[0],8,1)
y_test=Y_test.reshape(Y_test.shape[0],1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 8, 1)
# (40, 8, 1)
# (160, 1)
# (40, 1)

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(5, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
input_shape = x_train.shape[1:]

# %%
x_train.shape[1:]
# Out:
# (8, 1)

# %%
model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.3,
    dropout=0.3,
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["sparse_categorical_accuracy"],
)
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)]

history=model.fit(x_train,y_train,validation_split=0.2,epochs=200,batch_size=2,callbacks=callbacks,)

score=model.evaluate(x_test,y_test,batch_size=2)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 8, 1)]               0         []
#
#  layer_normalization (Layer  (None, 8, 1)                 2         ['input_1[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 8, 1)                 7169      ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  dropout (Dropout)           (None, 8, 1)                 0         ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 8, 1)                 0         ['dropout[0][0]',
#  Lambda)                                                             'input_1[0][0]']
#
#  layer_normalization_1 (Lay  (None, 8, 1)                 2         ['tf.__operators__.add[0][0]']
#  erNormalization)
#
#  conv1d (Conv1D)             (None, 8, 4)                 8         ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 8, 4)                 0         ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 8, 1)                 5         ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 8, 1)                 0         ['conv1d_1[0][0]',
#  OpLambda)                                                           'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 8, 1)                 2         ['tf.__operators__.add_1[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_1 (Mu  (None, 8, 1)                 7169      ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  dropout_2 (Dropout)         (None, 8, 1)                 0         ['multi_head_attention_1[0][0]
#                                                                     ']
#
#  tf.__operators__.add_2 (TF  (None, 8, 1)                 0         ['dropout_2[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  layer_normalization_3 (Lay  (None, 8, 1)                 2         ['tf.__operators__.add_2[0][0]
#  erNormalization)                                                   ']
#
#  conv1d_2 (Conv1D)           (None, 8, 4)                 8         ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 8, 4)                 0         ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 8, 1)                 5         ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 8, 1)                 0         ['conv1d_3[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  layer_normalization_4 (Lay  (None, 8, 1)                 2         ['tf.__operators__.add_3[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_2 (Mu  (None, 8, 1)                 7169      ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  dropout_4 (Dropout)         (None, 8, 1)                 0         ['multi_head_attention_2[0][0]
#                                                                     ']
#
#  tf.__operators__.add_4 (TF  (None, 8, 1)                 0         ['dropout_4[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  layer_normalization_5 (Lay  (None, 8, 1)                 2         ['tf.__operators__.add_4[0][0]
#  erNormalization)                                                   ']
#
#  conv1d_4 (Conv1D)           (None, 8, 4)                 8         ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 8, 4)                 0         ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 8, 1)                 5         ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 8, 1)                 0         ['conv1d_5[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  layer_normalization_6 (Lay  (None, 8, 1)                 2         ['tf.__operators__.add_5[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_3 (Mu  (None, 8, 1)                 7169      ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 8, 1)                 0         ['multi_head_attention_3[0][0]
#                                                                     ']
#
#  tf.__operators__.add_6 (TF  (None, 8, 1)                 0         ['dropout_6[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  layer_normalization_7 (Lay  (None, 8, 1)                 2         ['tf.__operators__.add_6[0][0]
#  erNormalization)                                                   ']
#
#  conv1d_6 (Conv1D)           (None, 8, 4)                 8         ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 8, 4)                 0         ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 8, 1)                 5         ['dropout_7[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 8, 1)                 0         ['conv1d_7[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  global_average_pooling1d (  (None, 8)                    0         ['tf.__operators__.add_7[0][0]
#  GlobalAveragePooling1D)                                            ']
#
#  dense (Dense)               (None, 128)                  1152      ['global_average_pooling1d[0][
#                                                                     0]']
#
#  dropout_8 (Dropout)         (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 5)                    645       ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 30541 (119.30 KB)
# Trainable params: 30541 (119.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 64/64 [==============================] - 14s 29ms/step - loss: 1.6784 - sparse_categorical_accuracy: 0.2656 - val_loss: 1.4168 - val_sparse_categorical_accuracy: 0.5625
# Epoch 2/200
# 64/64 [==============================] - 1s 11ms/step - loss: 1.3662 - sparse_categorical_accuracy: 0.4297 - val_loss: 1.1012 - val_sparse_categorical_accuracy: 0.5625
# Epoch 3/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.1937 - sparse_categorical_accuracy: 0.4922 - val_loss: 0.9429 - val_sparse_categorical_accuracy: 0.5625
# Epoch 4/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.0808 - sparse_categorical_accuracy: 0.5312 - val_loss: 0.8522 - val_sparse_categorical_accuracy: 0.5625
# Epoch 5/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.9650 - sparse_categorical_accuracy: 0.5234 - val_loss: 0.7876 - val_sparse_categorical_accuracy: 0.5938
# Epoch 6/200
# 64/64 [==============================] - 1s 14ms/step - loss: 1.0448 - sparse_categorical_accuracy: 0.4531 - val_loss: 0.7574 - val_sparse_categorical_accuracy: 0.5938
# Epoch 7/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.9121 - sparse_categorical_accuracy: 0.5469 - val_loss: 0.7254 - val_sparse_categorical_accuracy: 0.5938
# Epoch 8/200
# 64/64 [==============================] - 1s 11ms/step - loss: 0.8850 - sparse_categorical_accuracy: 0.5625 - val_loss: 0.6989 - val_sparse_categorical_accuracy: 0.6250
# Epoch 9/200
# 64/64 [==============================] - 1s 12ms/step - loss: 0.8840 - sparse_categorical_accuracy: 0.5234 - val_loss: 0.6795 - val_sparse_categorical_accuracy: 0.6875
# Epoch 10/200
# 64/64 [==============================] - 1s 13ms/step - loss: 0.8834 - sparse_categorical_accuracy: 0.5938 - val_loss: 0.6645 - val_sparse_categorical_accuracy: 0.6875
# Epoch 11/200
# 64/64 [==============================] - 1s 12ms/step - loss: 0.7928 - sparse_categorical_accuracy: 0.6016 - val_loss: 0.6410 - val_sparse_categorical_accuracy: 0.7188
# Epoch 12/200
# 64/64 [==============================] - 1s 12ms/step - loss: 0.7558 - sparse_categorical_accuracy: 0.6172 - val_loss: 0.6210 - val_sparse_categorical_accuracy: 0.7188
# Epoch 13/200
# 64/64 [==============================] - 1s 10ms/step - loss: 0.7404 - sparse_categorical_accuracy: 0.6328 - val_loss: 0.6042 - val_sparse_categorical_accuracy: 0.7188
# Epoch 14/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.8046 - sparse_categorical_accuracy: 0.6172 - val_loss: 0.5954 - val_sparse_categorical_accuracy: 0.7188
# Epoch 15/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.7919 - sparse_categorical_accuracy: 0.6328 - val_loss: 0.5891 - val_sparse_categorical_accuracy: 0.7188
# Epoch 16/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.7061 - sparse_categorical_accuracy: 0.7266 - val_loss: 0.5734 - val_sparse_categorical_accuracy: 0.7188
# Epoch 17/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.6882 - sparse_categorical_accuracy: 0.6797 - val_loss: 0.5672 - val_sparse_categorical_accuracy: 0.7188
# Epoch 18/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.7046 - sparse_categorical_accuracy: 0.6406 - val_loss: 0.5571 - val_sparse_categorical_accuracy: 0.7188
# Epoch 19/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.8176 - sparse_categorical_accuracy: 0.5703 - val_loss: 0.5630 - val_sparse_categorical_accuracy: 0.7500
# Epoch 20/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.7494 - sparse_categorical_accuracy: 0.5859 - val_loss: 0.5612 - val_sparse_categorical_accuracy: 0.7500
# Epoch 21/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.7503 - sparse_categorical_accuracy: 0.6406 - val_loss: 0.5573 - val_sparse_categorical_accuracy: 0.7500
# Epoch 22/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.6492 - sparse_categorical_accuracy: 0.7031 - val_loss: 0.5508 - val_sparse_categorical_accuracy: 0.7188
# Epoch 23/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.6080 - sparse_categorical_accuracy: 0.7500 - val_loss: 0.5332 - val_sparse_categorical_accuracy: 0.7500
# Epoch 24/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.6661 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.5295 - val_sparse_categorical_accuracy: 0.7500
# Epoch 25/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.6305 - sparse_categorical_accuracy: 0.7109 - val_loss: 0.5204 - val_sparse_categorical_accuracy: 0.7500
# Epoch 26/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.6662 - sparse_categorical_accuracy: 0.6953 - val_loss: 0.5205 - val_sparse_categorical_accuracy: 0.7500
# Epoch 27/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.6198 - sparse_categorical_accuracy: 0.7344 - val_loss: 0.5180 - val_sparse_categorical_accuracy: 0.7500
# Epoch 28/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.6413 - sparse_categorical_accuracy: 0.7031 - val_loss: 0.5126 - val_sparse_categorical_accuracy: 0.7500
# Epoch 29/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.6182 - sparse_categorical_accuracy: 0.7344 - val_loss: 0.5116 - val_sparse_categorical_accuracy: 0.8125
# Epoch 30/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.5677 - sparse_categorical_accuracy: 0.7422 - val_loss: 0.5015 - val_sparse_categorical_accuracy: 0.7500
# Epoch 31/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.5573 - sparse_categorical_accuracy: 0.7422 - val_loss: 0.4956 - val_sparse_categorical_accuracy: 0.7812
# Epoch 32/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.5853 - sparse_categorical_accuracy: 0.7734 - val_loss: 0.4939 - val_sparse_categorical_accuracy: 0.8125
# Epoch 33/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.6077 - sparse_categorical_accuracy: 0.7812 - val_loss: 0.4930 - val_sparse_categorical_accuracy: 0.8125
# Epoch 34/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.5707 - sparse_categorical_accuracy: 0.7969 - val_loss: 0.4832 - val_sparse_categorical_accuracy: 0.8125
# Epoch 35/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.5170 - sparse_categorical_accuracy: 0.7891 - val_loss: 0.4775 - val_sparse_categorical_accuracy: 0.8125
# Epoch 36/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.5402 - sparse_categorical_accuracy: 0.7344 - val_loss: 0.4702 - val_sparse_categorical_accuracy: 0.8125
# Epoch 37/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.5353 - sparse_categorical_accuracy: 0.7891 - val_loss: 0.4673 - val_sparse_categorical_accuracy: 0.8438
# Epoch 38/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.5043 - sparse_categorical_accuracy: 0.7969 - val_loss: 0.4575 - val_sparse_categorical_accuracy: 0.8438
# Epoch 39/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.5060 - sparse_categorical_accuracy: 0.7812 - val_loss: 0.4505 - val_sparse_categorical_accuracy: 0.8438
# Epoch 40/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.4856 - sparse_categorical_accuracy: 0.7969 - val_loss: 0.4441 - val_sparse_categorical_accuracy: 0.8438
# Epoch 41/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.4965 - sparse_categorical_accuracy: 0.7969 - val_loss: 0.4425 - val_sparse_categorical_accuracy: 0.8438
# Epoch 42/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.4826 - sparse_categorical_accuracy: 0.8359 - val_loss: 0.4327 - val_sparse_categorical_accuracy: 0.8438
# Epoch 43/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.4438 - sparse_categorical_accuracy: 0.8359 - val_loss: 0.4242 - val_sparse_categorical_accuracy: 0.8438
# Epoch 44/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4838 - sparse_categorical_accuracy: 0.8281 - val_loss: 0.4185 - val_sparse_categorical_accuracy: 0.8438
# Epoch 45/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.4481 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.4150 - val_sparse_categorical_accuracy: 0.8438
# Epoch 46/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4264 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.4072 - val_sparse_categorical_accuracy: 0.8438
# Epoch 47/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.4655 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.4118 - val_sparse_categorical_accuracy: 0.9062
# Epoch 48/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4438 - sparse_categorical_accuracy: 0.8516 - val_loss: 0.3998 - val_sparse_categorical_accuracy: 0.8750
# Epoch 49/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.4346 - sparse_categorical_accuracy: 0.8281 - val_loss: 0.3919 - val_sparse_categorical_accuracy: 0.8438
# Epoch 50/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.4340 - sparse_categorical_accuracy: 0.8594 - val_loss: 0.3901 - val_sparse_categorical_accuracy: 0.9062
# Epoch 51/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4154 - sparse_categorical_accuracy: 0.8438 - val_loss: 0.3830 - val_sparse_categorical_accuracy: 0.8750
# Epoch 52/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.4319 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.3776 - val_sparse_categorical_accuracy: 0.8438
# Epoch 53/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.4154 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.3811 - val_sparse_categorical_accuracy: 0.8750
# Epoch 54/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3860 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.3703 - val_sparse_categorical_accuracy: 0.9062
# Epoch 55/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.4011 - sparse_categorical_accuracy: 0.8594 - val_loss: 0.3680 - val_sparse_categorical_accuracy: 0.9062
# Epoch 56/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.3836 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.3611 - val_sparse_categorical_accuracy: 0.9062
# Epoch 57/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.4150 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.3618 - val_sparse_categorical_accuracy: 0.8750
# Epoch 58/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.3671 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.3549 - val_sparse_categorical_accuracy: 0.9062
# Epoch 59/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.3668 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.3522 - val_sparse_categorical_accuracy: 0.8750
# Epoch 60/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.3675 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.3471 - val_sparse_categorical_accuracy: 0.8750
# Epoch 61/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.3630 - sparse_categorical_accuracy: 0.8438 - val_loss: 0.3451 - val_sparse_categorical_accuracy: 0.8750
# Epoch 62/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.3635 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.3377 - val_sparse_categorical_accuracy: 0.9062
# Epoch 63/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3453 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8750
# Epoch 64/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.3341 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.3333 - val_sparse_categorical_accuracy: 0.8750
# Epoch 65/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3481 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.3358 - val_sparse_categorical_accuracy: 0.8438
# Epoch 66/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.3350 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.3272 - val_sparse_categorical_accuracy: 0.8750
# Epoch 67/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3377 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.3284 - val_sparse_categorical_accuracy: 0.8438
# Epoch 68/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3424 - sparse_categorical_accuracy: 0.8594 - val_loss: 0.3233 - val_sparse_categorical_accuracy: 0.8438
# Epoch 69/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3371 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.3260 - val_sparse_categorical_accuracy: 0.8438
# Epoch 70/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3245 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.3169 - val_sparse_categorical_accuracy: 0.8438
# Epoch 71/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3130 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.3111 - val_sparse_categorical_accuracy: 0.8750
# Epoch 72/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3043 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.3082 - val_sparse_categorical_accuracy: 0.8750
# Epoch 73/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.3321 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.3077 - val_sparse_categorical_accuracy: 0.8438
# Epoch 74/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.3072 - sparse_categorical_accuracy: 0.8594 - val_loss: 0.3069 - val_sparse_categorical_accuracy: 0.8438
# Epoch 75/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.3040 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.3075 - val_sparse_categorical_accuracy: 0.8438
# Epoch 76/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2994 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.3044 - val_sparse_categorical_accuracy: 0.8438
# Epoch 77/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2998 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.3001 - val_sparse_categorical_accuracy: 0.8438
# Epoch 78/200
# 64/64 [==============================] - 1s 11ms/step - loss: 0.2990 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.3007 - val_sparse_categorical_accuracy: 0.8438
# Epoch 79/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2717 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.3014 - val_sparse_categorical_accuracy: 0.8438
# Epoch 80/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2853 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2900 - val_sparse_categorical_accuracy: 0.8750
# Epoch 81/200
# 64/64 [==============================] - 0s 8ms/step - loss: 0.2973 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.2905 - val_sparse_categorical_accuracy: 0.8438
# Epoch 82/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2767 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2894 - val_sparse_categorical_accuracy: 0.8438
# Epoch 83/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2646 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.2837 - val_sparse_categorical_accuracy: 0.8750
# Epoch 84/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2911 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2881 - val_sparse_categorical_accuracy: 0.8438
# Epoch 85/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2721 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.2856 - val_sparse_categorical_accuracy: 0.8438
# Epoch 86/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2726 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2907 - val_sparse_categorical_accuracy: 0.8438
# Epoch 87/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2676 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2859 - val_sparse_categorical_accuracy: 0.8438
# Epoch 88/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2569 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2831 - val_sparse_categorical_accuracy: 0.8438
# Epoch 89/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2529 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2746 - val_sparse_categorical_accuracy: 0.8438
# Epoch 90/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2650 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2786 - val_sparse_categorical_accuracy: 0.8438
# Epoch 91/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2654 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2758 - val_sparse_categorical_accuracy: 0.8438
# Epoch 92/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2495 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.2743 - val_sparse_categorical_accuracy: 0.8438
# Epoch 93/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2504 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2793 - val_sparse_categorical_accuracy: 0.8750
# Epoch 94/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2498 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.2759 - val_sparse_categorical_accuracy: 0.8438
# Epoch 95/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2411 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2756 - val_sparse_categorical_accuracy: 0.8750
# Epoch 96/200
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2492 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2690 - val_sparse_categorical_accuracy: 0.8750
# Epoch 97/200
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2388 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.2755 - val_sparse_categorical_accuracy: 0.8750
# Epoch 98/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2327 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.2685 - val_sparse_categorical_accuracy: 0.8438
# Epoch 99/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2341 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.2756 - val_sparse_categorical_accuracy: 0.8750
# Epoch 100/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2413 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2722 - val_sparse_categorical_accuracy: 0.8750
# Epoch 101/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2392 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2685 - val_sparse_categorical_accuracy: 0.8750
# Epoch 102/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2304 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2658 - val_sparse_categorical_accuracy: 0.8750
# Epoch 103/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2357 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2691 - val_sparse_categorical_accuracy: 0.8750
# Epoch 104/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2373 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2620 - val_sparse_categorical_accuracy: 0.8438
# Epoch 105/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2390 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2707 - val_sparse_categorical_accuracy: 0.8750
# Epoch 106/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2376 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2665 - val_sparse_categorical_accuracy: 0.8750
# Epoch 107/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2337 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2591 - val_sparse_categorical_accuracy: 0.8438
# Epoch 108/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2274 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2616 - val_sparse_categorical_accuracy: 0.8750
# Epoch 109/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2199 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2568 - val_sparse_categorical_accuracy: 0.8750
# Epoch 110/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2191 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2606 - val_sparse_categorical_accuracy: 0.8750
# Epoch 111/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2181 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2562 - val_sparse_categorical_accuracy: 0.8438
# Epoch 112/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2231 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2601 - val_sparse_categorical_accuracy: 0.8750
# Epoch 113/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2219 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2550 - val_sparse_categorical_accuracy: 0.8750
# Epoch 114/200
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2070 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2550 - val_sparse_categorical_accuracy: 0.8750
# Epoch 115/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2229 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2544 - val_sparse_categorical_accuracy: 0.8750
# Epoch 116/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2241 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2524 - val_sparse_categorical_accuracy: 0.8438
# Epoch 117/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2289 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2554 - val_sparse_categorical_accuracy: 0.8750
# Epoch 118/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2063 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2527 - val_sparse_categorical_accuracy: 0.8750
# Epoch 119/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2121 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2528 - val_sparse_categorical_accuracy: 0.8750
# Epoch 120/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2104 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2520 - val_sparse_categorical_accuracy: 0.8750
# Epoch 121/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2184 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2543 - val_sparse_categorical_accuracy: 0.8750
# Epoch 122/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2145 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2556 - val_sparse_categorical_accuracy: 0.8750
# Epoch 123/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2171 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2509 - val_sparse_categorical_accuracy: 0.8750
# Epoch 124/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2030 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2519 - val_sparse_categorical_accuracy: 0.8750
# Epoch 125/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2137 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2500 - val_sparse_categorical_accuracy: 0.8750
# Epoch 126/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2158 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2507 - val_sparse_categorical_accuracy: 0.8750
# Epoch 127/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2116 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2499 - val_sparse_categorical_accuracy: 0.8750
# Epoch 128/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2184 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2533 - val_sparse_categorical_accuracy: 0.8750
# Epoch 129/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2026 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2495 - val_sparse_categorical_accuracy: 0.8750
# Epoch 130/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2013 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2494 - val_sparse_categorical_accuracy: 0.8750
# Epoch 131/200
# 64/64 [==============================] - 0s 5ms/step - loss: 0.1926 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2487 - val_sparse_categorical_accuracy: 0.8750
# Epoch 132/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1960 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2493 - val_sparse_categorical_accuracy: 0.8750
# Epoch 133/200
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2164 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2494 - val_sparse_categorical_accuracy: 0.8750
# Epoch 134/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1874 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2470 - val_sparse_categorical_accuracy: 0.8750
# Epoch 135/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1918 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2460 - val_sparse_categorical_accuracy: 0.8750
# Epoch 136/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2034 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2480 - val_sparse_categorical_accuracy: 0.8750
# Epoch 137/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2033 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2460 - val_sparse_categorical_accuracy: 0.8750
# Epoch 138/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2035 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.2476 - val_sparse_categorical_accuracy: 0.8750
# Epoch 139/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1985 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2452 - val_sparse_categorical_accuracy: 0.8750
# Epoch 140/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1952 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2460 - val_sparse_categorical_accuracy: 0.8750
# Epoch 141/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1859 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2454 - val_sparse_categorical_accuracy: 0.8750
# Epoch 142/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2000 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2438 - val_sparse_categorical_accuracy: 0.8750
# Epoch 143/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1878 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2459 - val_sparse_categorical_accuracy: 0.8750
# Epoch 144/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1986 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2447 - val_sparse_categorical_accuracy: 0.8750
# Epoch 145/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1880 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2442 - val_sparse_categorical_accuracy: 0.8750
# Epoch 146/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1740 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2441 - val_sparse_categorical_accuracy: 0.8750
# Epoch 147/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1951 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2438 - val_sparse_categorical_accuracy: 0.8750
# Epoch 148/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1962 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2451 - val_sparse_categorical_accuracy: 0.8750
# Epoch 149/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1913 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2431 - val_sparse_categorical_accuracy: 0.8750
# Epoch 150/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2077 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2424 - val_sparse_categorical_accuracy: 0.8750
# Epoch 151/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1748 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2441 - val_sparse_categorical_accuracy: 0.8750
# Epoch 152/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1652 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2435 - val_sparse_categorical_accuracy: 0.8750
# Epoch 153/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1752 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2429 - val_sparse_categorical_accuracy: 0.8750
# Epoch 154/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1673 - sparse_categorical_accuracy: 0.9453 - val_loss: 0.2421 - val_sparse_categorical_accuracy: 0.8750
# Epoch 155/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1882 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2422 - val_sparse_categorical_accuracy: 0.8750
# Epoch 156/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1852 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2408 - val_sparse_categorical_accuracy: 0.8750
# Epoch 157/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1952 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2407 - val_sparse_categorical_accuracy: 0.8750
# Epoch 158/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1889 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2406 - val_sparse_categorical_accuracy: 0.8750
# Epoch 159/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1710 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2411 - val_sparse_categorical_accuracy: 0.8750
# Epoch 160/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1736 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2405 - val_sparse_categorical_accuracy: 0.8750
# Epoch 161/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1759 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2400 - val_sparse_categorical_accuracy: 0.8750
# Epoch 162/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1869 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2404 - val_sparse_categorical_accuracy: 0.8750
# Epoch 163/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1818 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2414 - val_sparse_categorical_accuracy: 0.8750
# Epoch 164/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1632 - sparse_categorical_accuracy: 0.9531 - val_loss: 0.2393 - val_sparse_categorical_accuracy: 0.8750
# Epoch 165/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1544 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2393 - val_sparse_categorical_accuracy: 0.9062
# Epoch 166/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1872 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2394 - val_sparse_categorical_accuracy: 0.8750
# Epoch 167/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2017 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2415 - val_sparse_categorical_accuracy: 0.8750
# Epoch 168/200
# 64/64 [==============================] - 0s 5ms/step - loss: 0.1835 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2393 - val_sparse_categorical_accuracy: 0.9062
# Epoch 169/200
# 64/64 [==============================] - 0s 5ms/step - loss: 0.1662 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2415 - val_sparse_categorical_accuracy: 0.8750
# Epoch 170/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1690 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2398 - val_sparse_categorical_accuracy: 0.8750
# Epoch 171/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1697 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2393 - val_sparse_categorical_accuracy: 0.9062
# Epoch 172/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1603 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2399 - val_sparse_categorical_accuracy: 0.8750
# Epoch 173/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1783 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2400 - val_sparse_categorical_accuracy: 0.8750
# Epoch 174/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1685 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2387 - val_sparse_categorical_accuracy: 0.9062
# Epoch 175/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1735 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2388 - val_sparse_categorical_accuracy: 0.9062
# Epoch 176/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1760 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2384 - val_sparse_categorical_accuracy: 0.9062
# Epoch 177/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1711 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2392 - val_sparse_categorical_accuracy: 0.8750
# Epoch 178/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1709 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2388 - val_sparse_categorical_accuracy: 0.9062
# Epoch 179/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1654 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2401 - val_sparse_categorical_accuracy: 0.8750
# Epoch 180/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1637 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2395 - val_sparse_categorical_accuracy: 0.8750
# Epoch 181/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1827 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2398 - val_sparse_categorical_accuracy: 0.8750
# Epoch 182/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1761 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2401 - val_sparse_categorical_accuracy: 0.8750
# Epoch 183/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1621 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2388 - val_sparse_categorical_accuracy: 0.8750
# Epoch 184/200
# 64/64 [==============================] - 0s 5ms/step - loss: 0.1617 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2390 - val_sparse_categorical_accuracy: 0.8750
# Epoch 185/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1753 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2392 - val_sparse_categorical_accuracy: 0.8750
# Epoch 186/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1608 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2390 - val_sparse_categorical_accuracy: 0.8750
# Epoch 187/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1697 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2389 - val_sparse_categorical_accuracy: 0.8750
# Epoch 188/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1617 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2384 - val_sparse_categorical_accuracy: 0.8750
# Epoch 189/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1589 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2382 - val_sparse_categorical_accuracy: 0.9062
# Epoch 190/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1618 - sparse_categorical_accuracy: 0.9453 - val_loss: 0.2388 - val_sparse_categorical_accuracy: 0.8750
# Epoch 191/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1476 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2397 - val_sparse_categorical_accuracy: 0.8750
# Epoch 192/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1668 - sparse_categorical_accuracy: 0.9453 - val_loss: 0.2389 - val_sparse_categorical_accuracy: 0.8750
# Epoch 193/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1466 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2379 - val_sparse_categorical_accuracy: 0.9062
# Epoch 194/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1689 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2379 - val_sparse_categorical_accuracy: 0.9062
# Epoch 195/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1666 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2378 - val_sparse_categorical_accuracy: 0.8750
# Epoch 196/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1646 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2377 - val_sparse_categorical_accuracy: 0.9062
# Epoch 197/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1546 - sparse_categorical_accuracy: 0.9453 - val_loss: 0.2371 - val_sparse_categorical_accuracy: 0.9062
# Epoch 198/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1620 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2374 - val_sparse_categorical_accuracy: 0.9062
# Epoch 199/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1571 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2377 - val_sparse_categorical_accuracy: 0.8750
# Epoch 200/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.1624 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.2377 - val_sparse_categorical_accuracy: 0.9062
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1029 - sparse_categorical_accuracy: 1.0000

# %%
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('D vs E')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train_acc','Test_acc'],loc='best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('D vs E')
plt.xlabel('Epochs')
plt.ylabel('Crossentropy_Loss')
plt.legend(['Train_loss','Test_loss'],loc='best')
plt.show()

# %%
clf = SVC(random_state=0)
clf.fit(X_train, Y_train)
predictions = clf.predict(X_test)
cm = confusion_matrix(Y_test, predictions, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot()
plt.show()
# Out:
# C:\Users\Sandeep\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
print('Precision: %.3f' % precision_score(Y_test, predictions))
print('Recall: %.3f' % recall_score(y_test, predictions))
print('Accuracy: %.3f' % accuracy_score(y_test, predictions))
print('F1 Score: %.3f' % f1_score(y_test, predictions))
# Out:
# Precision: 1.000
# Recall: 0.909
# Accuracy: 0.950
# F1 Score: 0.952

# %%
score, acc = model.evaluate(x_test, y_test,
                            batch_size=4)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1029 - sparse_categorical_accuracy: 1.0000
# Test score: 0.10289186239242554
# Test accuracy: 1.0
